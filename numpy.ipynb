# %% [markdown]
# # Numpy

# %%
# marks=[10,20,30,40,50]
import numpy as np
print(np.__version__)

# %% [markdown]
# # Numpy array

# %%
import numpy as np
numbers=np.array([1,2,3,4,5])
print(numbers)
print(type(numbers))

# %% [markdown]
# # Automatic Datatypes

# %%
import numpy as np
a = np.array([1,2,3.5,4,5.5])
print(a)
print(a.dtype)
# Out:
# [1.  2.  3.5 4.  5.5]
# float64

# %% [markdown]
# # Zeros

# %%
import numpy as np
a = np.zeros([5])
print(a)
# Out:
# [0. 0. 0. 0. 0.]
