# %% [markdown]
# # Numpy

# %%
# marks=[10,20,30,40,50]
import numpy as np
print(np.__version__)

# %% [markdown]
# # Numpy array

# %%
import numpy as np
numbers=np.array([1,2,3,4,5])
print(numbers)
print(type(numbers))
